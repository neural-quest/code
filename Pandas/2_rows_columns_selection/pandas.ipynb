# %% [markdown]
# ## Tutorial-1: Introduction to Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("ipl_dataset.csv")

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.shape
# Out:
# (816, 17)

# %%
df.head(2)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1          Chennai Super Kings           bat    Chennai Super Kings   runs
#
#    result_margin eliminator method    umpire1      umpire2
# 0          140.0          N    NaN  Asad Rauf  RE Koertzen
# 1           33.0          N    NaN  MR Benson   SL Shastri

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
# ## Tutorial-2: Selecting rows and columns from dataframes

# %%
df.head(3)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
# 2             Delhi Daredevils       Rajasthan Royals
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 1          Chennai Super Kings           bat    Chennai Super Kings     runs
# ...

# %%
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
df["player_of_match"]
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
df[["player_of_match", "team1", "team2"]]
# Out:
#     player_of_match                        team1                        team2
# 0       BB McCullum  Royal Challengers Bangalore        Kolkata Knight Riders
# 1        MEK Hussey              Kings XI Punjab          Chennai Super Kings
# 2       MF Maharoof             Delhi Daredevils             Rajasthan Royals
# 3        MV Boucher               Mumbai Indians  Royal Challengers Bangalore
# 4         DJ Hussey        Kolkata Knight Riders              Deccan Chargers
# ..              ...                          ...                          ...
# 811  AB de Villiers  Royal Challengers Bangalore               Mumbai Indians
# 812       JJ Bumrah               Mumbai Indians               Delhi Capitals
# 813   KS Williamson  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814      MP Stoinis               Delhi Capitals          Sunrisers Hyderabad
# 815        TA Boult               Delhi Capitals               Mumbai Indians
#
# [816 rows x 3 columns]

# %%
df.player_of_match
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
type(df["player_of_match"])
# Out:
# pandas.core.series.Series

# %%
loc
iloc

# %%
#iloc - allows to select rows and columns based on integer location

df.iloc[0]
# Out:
# id                                      335982
# city                                 Bangalore
# date                                2008-04-18
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# neutral_venue                                0
# team1              Royal Challengers Bangalore
# team2                    Kolkata Knight Riders
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            140.0
# eliminator                                   N
# method                                     NaN
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# Name: 0, dtype: object

# %%
df.iloc[0, 0]
# Out:
# 335982

# %%
df.iloc[[0,2,4,5]]
# Out:
#        id       city        date player_of_match                   venue  \
# 0  335982  Bangalore  2008-04-18     BB McCullum   M Chinnaswamy Stadium
# 2  335984      Delhi  2008-04-19     MF Maharoof        Feroz Shah Kotla
# 4  335986    Kolkata  2008-04-20       DJ Hussey            Eden Gardens
# 5  335987     Jaipur  2008-04-21       SR Watson  Sawai Mansingh Stadium
#
#    neutral_venue                        team1                  team2  \
# 0              0  Royal Challengers Bangalore  Kolkata Knight Riders
# 2              0             Delhi Daredevils       Rajasthan Royals
# 4              0        Kolkata Knight Riders        Deccan Chargers
# 5              0             Rajasthan Royals        Kings XI Punjab
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 2             Rajasthan Royals           bat       Delhi Daredevils  wickets
# ...

# %%
df.iloc[[0,2,4,5], [0,1,3]]
# Out:
#        id       city player_of_match
# 0  335982  Bangalore     BB McCullum
# 2  335984      Delhi     MF Maharoof
# 4  335986    Kolkata       DJ Hussey
# 5  335987     Jaipur       SR Watson

# %%
df.iloc[0:5, 1:10]
# Out:
#          city        date player_of_match  \
# 0   Bangalore  2008-04-18     BB McCullum
# 1  Chandigarh  2008-04-19      MEK Hussey
# 2       Delhi  2008-04-19     MF Maharoof
# 3      Mumbai  2008-04-20      MV Boucher
# 4     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
# ...

# %%
loc - it allows us to select rows and columns based on the labels

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
test_df = df.iloc[5:10]

# %%
test_df
# Out:
#        id        city        date player_of_match  \
# 5  335987      Jaipur  2008-04-21       SR Watson
# 6  335988   Hyderabad  2008-04-22        V Sehwag
# 7  335989     Chennai  2008-04-23       ML Hayden
# 8  335990   Hyderabad  2008-04-24       YK Pathan
# 9  335991  Chandigarh  2008-04-25   KC Sangakkara
#
#                                         venue  neutral_venue  \
# 5                      Sawai Mansingh Stadium              0
# 6   Rajiv Gandhi International Stadium, Uppal              0
# 7             MA Chidambaram Stadium, Chepauk              0
# 8   Rajiv Gandhi International Stadium, Uppal              0
# 9  Punjab Cricket Association Stadium, Mohali              0
#
#                  team1             team2       toss_winner toss_decision  \
# 5     Rajasthan Royals   Kings XI Punjab   Kings XI Punjab           bat
# 6      Deccan Chargers  Delhi Daredevils   Deccan Chargers           bat
# ...

# %%
test_df.iloc[0]
# Out:
# id                                 335987
# city                               Jaipur
# date                           2008-04-21
# player_of_match                 SR Watson
# venue              Sawai Mansingh Stadium
# neutral_venue                           0
# team1                    Rajasthan Royals
# team2                     Kings XI Punjab
# toss_winner               Kings XI Punjab
# toss_decision                         bat
# winner                   Rajasthan Royals
# result                            wickets
# result_margin                         6.0
# eliminator                              N
# method                                NaN
# umpire1                         Aleem Dar
# umpire2                         RB Tiffin
# Name: 5, dtype: object

# %%
test_df.loc[5]
# Out:
# id                                 335987
# city                               Jaipur
# date                           2008-04-21
# player_of_match                 SR Watson
# venue              Sawai Mansingh Stadium
# neutral_venue                           0
# team1                    Rajasthan Royals
# team2                     Kings XI Punjab
# toss_winner               Kings XI Punjab
# toss_decision                         bat
# winner                   Rajasthan Royals
# result                            wickets
# result_margin                         6.0
# eliminator                              N
# method                                NaN
# umpire1                         Aleem Dar
# umpire2                         RB Tiffin
# Name: 5, dtype: object

# %%
test_df.loc[5, "city"]
# Out:
# 'Jaipur'

# %%
test_df.loc[[5,6,7], ["player_of_match", "team1", "team2"]]
# Out:
#   player_of_match                team1             team2
# 5       SR Watson     Rajasthan Royals   Kings XI Punjab
# 6        V Sehwag      Deccan Chargers  Delhi Daredevils
# 7       ML Hayden  Chennai Super Kings    Mumbai Indians

# %%
test_df.loc[5:9, "player_of_match":"winner"]
# Out:
#   player_of_match                                       venue  neutral_venue  \
# 5       SR Watson                      Sawai Mansingh Stadium              0
# 6        V Sehwag   Rajiv Gandhi International Stadium, Uppal              0
# 7       ML Hayden             MA Chidambaram Stadium, Chepauk              0
# 8       YK Pathan   Rajiv Gandhi International Stadium, Uppal              0
# 9   KC Sangakkara  Punjab Cricket Association Stadium, Mohali              0
#
#                  team1             team2       toss_winner toss_decision  \
# 5     Rajasthan Royals   Kings XI Punjab   Kings XI Punjab           bat
# 6      Deccan Chargers  Delhi Daredevils   Deccan Chargers           bat
# 7  Chennai Super Kings    Mumbai Indians    Mumbai Indians         field
# 8      Deccan Chargers  Rajasthan Royals  Rajasthan Royals         field
# 9      Kings XI Punjab    Mumbai Indians    Mumbai Indians         field
#
#                 winner
# 5     Rajasthan Royals
# ...
